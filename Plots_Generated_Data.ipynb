# %%
import csv
import numpy as np
import pandas as pd
from numpy import savetxt
import matplotlib.pyplot as plt

# %%
data_g_2 = pd.read_csv("./three_nodes_data_g_2.csv")
data_g_2 = pd.DataFrame(data_g_2)

data_g_4 = pd.read_csv("./three_nodes_data_g_4.csv")
#data_g_4 = pd.array(data_g_4)

data_g_6 = pd.read_csv("./three_nodes_data_g_6.csv")
data_g_6 = data_g_6.values


data_g_6 = pd.read_csv("./three_nodes_data_g_6.csv")
data_g_6 = data_g_6.values

data_g_6 = pd.read_csv("./three_nodes_data_g_6.csv")
data_g_6 = data_g_6.values

data_g_6 = pd.read_csv("./three_nodes_data_g_6.csv")
data_g_6 = data_g_6.values

data_g_6 = pd.read_csv("./three_nodes_data_g_6.csv").values
#data_g_6 = data_g_6.values

# %%
plt.plot(data_g_2[:3000])
plt.ylabel('solution y(t)')
plt.xlabel('time steps')
plt.title("Stimulation u==4")
plt.show()

# %%
plt.plot(data_g_4[:1000])
plt.ylabel('solution y(t)')
plt.xlabel('time steps')
plt.title("Stimulation u==2")
plt.show()

# %%
plt.plot(data_g_6[:3000,:3])
plt.ylabel('solution y(t)')
plt.xlabel('time steps')
plt.title("Stimulation u==0")
plt.show()
